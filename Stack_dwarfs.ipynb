# %% [markdown]
# # Stacking of Dwarf AGN

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import matplotlib
import numpy as np
matplotlib.interactive(True)

from tracing_TS import trace_profile
from fermi_utils import get_pars, open_txt

# %% [markdown]
# # Tracing TS profile with source localization

# %% [markdown]
# # Sources
#
# Paper ID: Optical Narrow-Line ratios (RO, Reines et al. 2013), [Fe X] emission (Mo, Molina et al. 2020), Strong compact Radio source (RR, Reines et al. 2019), X-rays (BalX, Baldassare et al. 2017; GHX Greene & Ho 2004; BiX , Birchall et al. 2020), Ionized Molecular Outflows (MK, MK et al. ??)
#
#
#
# Paper https://arxiv.org/pdf/1909.04670.pdf

# %%
SourceTag = ['O1', 'O2', 'O3', 'O4', 'O5', 'O6', 'O7', 'O8',  'O9', 'O10', 'O11',
             'O12', 'O13', 'O14', 'O15', 'O16', 'O17', 'O18', 'O19', 'O20', 'O21',
             'O22', 'O23', 'O24','O25', 'O26', 'O27', 'O28', 'O29', 'O30', 'O31','O32', 'O33',
             'O34', 'O35', 'O36', 'O37', 'O38', 'O39', 'O40', 'O41', 'O42', 'O43', 'O44', 'O45',
             'O46', 'O47', 'O48', 'O49', 'O50', 'O51', 'O52', 'O53', 'O54', 'O55', 'O56', 'O57', 
             'O58', 'O59', 'O60', 'O61', 'O62', 'W1', 'W2', 'W3',
             'O66', 'O67', 'O68','O69','O70', 'O71','O72',
             'R_1', 'R_2', 'R_3', 'R_4', 'R_5', 'R_6', 'R_7', 'R_8', 'R_9', 'R_10', 'R_11', 
             'R_12','R_13','R_14', 'R_15', 'R_16', 'R_17', 'R_18', 'R_19', 'R_20', 'R_21',
             'X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9','X10', 'X11', 'X12', 'X13', 'X14', 'X15',
             'X16', 'X17', 'X18', 'X19', 'X20', 'X21', 'X22', 'X23', 'X24', 'X25', 'X26', 'X27', 'X28', 'X29', 'X30']

ST = ['O1', 'O2', 'O3', 'O4', 'O5', 'O6', 'O7', 'O8', 'O9', 'O10', 'O11', 'O12', 'O13', 'O14', 'O15', 'O16', 'O17', 'O18', 'O19', 'O20', 'O21', 'O22', 'O23', 'O24','O25', 'O26', 'O27', 'O28', 'O29', 'O30', 'O31', 'O32', 'O33','O34', 'O35', 'O36', 'O37', 'O38', 'O39', 'O40', 'O41', 'O42', 'O43', 'O44', 'O45', 'O46', 'O47', 'O48', 'O49', 'O50', 'O51', 'O52', 'O53', 'O54', 'O55', 'O56', 'O57', 'O58', 'O59', 'O60', 'O61', 'O62', 'O63', 'O64', 'O65', 'O66', 'O67', 'O68','O69','O70','O71','O72',
      'R1', 'R2', 'R3', 'R4', 'R5', 'R6', 'R7', 'R8', 'R9', 'R10', 'R11', 'R12', 'R13', 'R14', 'R15', 'R16', 'R17', 'R18', 'R19', 'R20', 'R21',
      'X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11', 'X12', 'X13', 'X14', 'X15','X16', 'X17', 'X18', 'X19', 'X20', 'X21', 'X22', 'X23', 'X24', 'X25', 'X26', 'X27', 'X28', 'X29', 'X30']

paper_ID =  ['RO1/BalX', 'RO9/RR26/BalX', 'RO11/MK/BalX', 'RO20/Mo/BalX', 'RO21', 'RO32/BalX', 'RO48/BalX', 'RO119/BalX', 
             'RO123', 'RO127/BalX',  'RO105/Mo/He/X', 'RR38/Mo/He/X','Mo/He', 'Mo/R', 'Mo/BiX', 'Ba50l/Mo', 'Mo/O/IR', 
             'Mo/O/IR', 'Mo/O/IR', 'Mo/IR','Mo/IR','Mo/IR', 'Mo/IR', 'Mo/IR', 'Mo/O', 'Mo/IR', 'Mo/IR', 'Mo/IR', 'Mo/O', 
             'Mo/IR', 'Mo/IR', 'Mo/O', 'Mo/O', 'RO2', 'RO3', 'RO4/MK', 'RO5', 'RO6/MK', 'RO7', 'RO8', 'RO10', 'RO12/MK', 
             'RO13', 'RO14','RO15/BiX', 'RO16', 'RO17', 'RO18', 'RO19', 'RO22', 'RO23', 'RO24', 'RO25', 'RO26', 'RO27', 
             'RO28', 'RO29', 'RO30', 'RO31', 'RO33', 'RO34', 'RO35', 'MK', 'MK', 'MK', 'Mo', 'Mo/O','Mo','Mo', 'Mo', 'Mo','Mo',
             'RR2', 'RR6', 'RR48', 'RR64', 'RR65', 'RR83', 'RR25', 'RR28', 'RR33', 'RR77',  'RR82',  'RR92', 
             'RR98/Mo/x', 'Mo/R/X', 'Mo/R/X', 'ReB5', 'ReB10', 'ReB14', 'ReB20', 'ReB70', 'ReB111',
             'BiX', 'BiX', 'BiX', 'BiX', 'BiX', 'BiX', 'BiX', 'BiX', 'BiX', 'BiX', 'BiX', 'BiX', 'BiX', 'BiX', 'BiX', 'BiX', 'BiX', 'BiX', 'BiX', 'BiX', 'BiX', 'BiX', 'BiX', 'BiX', 'BiX', 'BiX', 'BiX', 'BiX', 'BiX', 'BiX']

NSA_ID = ['62996', '10779', '125318', '52675/256802', '89394', '15235', '47066', '79874', '18913', '99052', '56478/275961', '7/50','41675', '88972/427201','20020/95985', '131809','144266', '61339/300542', '345375', '532026', '553772', '577169', '59672/656364', '162348/670127', '10455/50800', '21501/102990', '36022/174326', '213780', '305229', '393631', '92705/442120', '442212', '96501/458829', '7480', '68765', '64339', '46677', '105376', '30020', '110040', '106134', '107272', '37942', '111644','27397', '30370', '101949', '113566', '92369', '77431', '89494', '104527', '51220', '54572', '78568', '70907', '71023', '123656', '71565', '120870', '124249', '64022', '74186', '6059', '123877', '1137/6055', '15288','5246/30143', '75167/366027', '86896/418928', '95166/452253', '100728/473078',
          '26027', '23750', '137386', '66255', '101782', '67389', '26634', '12478', '16467', '3323', '102751', '3602','692957', '100442/472272', '533731', '625882', '127796', '130010', '132555', '135554', '160437',
          '106801', '76401', '84201', '50679', '158384', '60658', '62285', '60412', '42891', '163937', '30811', '46668', '95588', '105283', '110109', '74195', '74278', '36968', '121041', '20558', '1120', '113915', '162072', '46305', '104152', '45115', '164911', '165409', '73400', '46031']


print(len(SourceTag), len(ST), len(paper_ID), len(NSA_ID))
sources_NSA = {SourceTag[i]:NSA_ID[i] for i in range(len(SourceTag))} # dict ST : NSA_ID 
sources_p = {SourceTag[i]:paper_ID[i] for i in range(len(SourceTag))} # dict ST : paper

# Optical targets
T1 = ['O1', 'O2', 'O3', 'O4', 'O5', 'O6', 'O7', 'O8',  'O9', 'O10', 'O11',
      'O34', 'O35', 'O36', 'O37', 'O38', 'O39', 'O40', 'O41', 'O42', 'O43', 
      'O44', 'O45', 'O46', 'O47', 'O48', 'O49', 'O50', 'O51', 'O52', 'O53', 
      'O54', 'O55', 'O56', 'O57', 'O58', 'O59', 'O60', 'O61', 'O62', 'O63', 'O64', 'O65', 
      'O17', 'O18', 'O19','O25', 'O29', 'O32', 'O33', 'O67']
      #'X3', 'X4','X6', 'X14']

# [Fe X] targets
T2 = ['O4', 'O11', 'O12', 'O13', 'O14', 'O15', 'O16', 'O17', 'O18', 'O19', 'O20', 'O21', 'O22', 'O23', 'O24','O25',
      'O26', 'O27', 'O28', 'O29', 'O30', 'O31', 'O32', 'O33', 'O66', 'O67', 'O68', 'O69','O70', 'O71', 'O72', 'R14',
      'R15','R16']

# Radio targets
T3 = ['O2', 'O12', 'O14','R1', 'R2', 'R3', 'R4', 'R5', 'R6', 'R7', 'R8', 'R9', 'R10', 'R11', 'R12', 'R13', 'R14', 'R15', 'R16', 'R17', 
      'R18', 'R19', 'R20', 'R21']

# X-ray targets
T4 = ['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9','X10', 'X11', 'X12', 'X13', 'X14', 'X15', 'X16', 'X17',
      'X18', 'X19', 'X20', 'X21', 'X22', 'X23', 'X24', 'X25', 'X26', 'X27', 'X28', 'X29', 'X30',
     'O1', 'O2', 'O3', 'O4', 'O6', 'O7', 'O8', 'O9', 'O10', 'O11', 'O12', 'O15', 'O45', 'R14', 'R15', 'R16']

# targets whose TS profile didn't converge
noconv = ['O29','O36', 'O45', 'O49',
          'X20','X24']

# targets less than 0.8 deg from know 4FGL DR2 source of now TS>16 source
close_4FGL = ['O9', 'O25', 'O36', 'O37', 'O38', 'O40','R1','R10', 'R11', 'R20', 'R13', 'X8', 'X11', 'X13', 'X19']
close_4FGL_d = [0.4, 0.2,  'Gal plane', 0.374, 0.331, 0.254, 0.3, 0.141, 'Gal plane', 0.3, 0.19,  0.41, 0.294, 0.284]

for n, i in enumerate(SourceTag):
    print(i,':', sources_NSA[i],'-',sources_p[i])

# %% [markdown]
# # trace_profile():

# %% [markdown]
# Code to trace TS profile as a function of photon spectrum index for a list of targets selected using Fermi-LAT gamma-ray data
#
#
#
# ---Inputs:
#
#         Names:         (list) List containing names of targets to trace TS profile
#
#         n_index:       (int) Number of photon index values perform fit
#
#         free_dist:     (float) Free parameters from sources inside this number of degrees from ROI center
#
#         opt:           (str) Fhoice of optimizer ('MINUIT', 'NEWMINUIT')
#
#         main_dir:      (str) Name of directory containing the folders for each ROI
#
#         config_file:   (str) Standard name of Config yaml file to be used in the analysis
#
#         loc_TS:        (float) Threshold to run the localize() method on the target source
#
#         loc_tol:       (float) Standard tolerance (in degrees) for distance between target and nearby source
#                     We use half this value as maximum tolerance for running the localize() method on our targets
#
#         load:          (bool) Load previous ROI state from an existing ROI.fits file
#
#         trace:         (bool) Do the tracing (True), or just verify other functionalities (False) like localize()
#
#         test_mocks:    (bool) Actually do the random mock source fitting to later compare with target results
#
#         n_mocks:       (int) Number of mock targets to generate per ROI
#
#         verb:          (int 0-3) Level of verbosity for printing the output of fermipy and tracing
#                                    recomend 1 for just the important stuff, or 3 for full details
#
#         make_plts:     (bool) Make png ROI plots like the count and TS maps

# %%
# targets whose TS profile didn't converge
retry = ['O5', 'O6', 'O16', 'O17', 'O19', 'O24', 'O66', 'O67', 'O70',
         'X2', 'X6', 'X9', 'X16', 'X17', 'X21', 'X27', 'X28', 'X29']

s = 0

for r in retry[s:]:
    do = [r]
    
    try:
        trace_profile(do, free_dist=5, loc_TS=4, loc_tol=0.8, opt='MINUIT', 
              load=False, trace=True, test_mocks=True, verb=1, make_plts=True)
    except:
        pass
    
    

from ipylab import JupyterFrontEnd
# save notebook and shutdown system
app = JupyterFrontEnd()
app.commands.execute('docmanager:save')

# !shutdown -h
# Out:
# Time for:  O5
# here
# ----Finding sources around O5
# O5 is 0.0 deg from the ROI center
# ----Closest source is PS J1231.3+3353 : TS = 23 , offset = 1.194
# WARNING:
#    Fit quality  3 Photon index =  3.2275023293941687
# ----Making TS Map
# ----Saving Results
# O5 : TS = 3
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  O6
# here
# ----Finding sources around O6
# O6 is 0.038 deg from the ROI center
# Closest source is PS J1437.9+0220 : TS = 34 , offset = 0.734 deg
# Moved PS J1437.9+0220 by:  0.009 deg, new offset = 0.725  deg
# 99% positional uncertainty:  0.096
# Target is outside r99
# WARNING:
#    Fit quality  3 Photon index =  3.341662757202262
# ----Making TS Map
# ----Saving Results
# O6 : TS = 3
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  O16
# here
# ----Finding sources around O16
# O16 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J0929.3+5014 : TS = 1248 , offset = 1.53
# WARNING:
#    Fit quality  3 Photon index =  2.0047022010694437
# ----Making TS Map
# ----Saving Results
# O16 : TS = 10
# ----Localizing O16
# Moved O16 by:  0.151 deg
# 99% positional uncertainty:  0.192 deg
# WARNING:
#    Fit quality  3 Photon index =  1.989689731073586
# Dist. from 4FGL J0929.3+5014 = 1.44 deg
# O16 : (after localizing) TS = 17
# ----Making TS Map
# ----Saving Results
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  O17
# here
# ----Finding sources around O17
# O17 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J1653.0+3640 : TS = 38 , offset = 0.556
# WARNING: 4FGL J1653.0+3640 proximity might interfere with the results for O17
# WARNING:
#    Fit quality  2 Photon index =  2.0073216595289116
# ----Making TS Map
# ----Saving Results
# O17 : TS = 0
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  O19
# here
# ----Finding sources around O19
# O19 is 0.029 deg from the ROI center
# ----Closest source is 4FGL J1254.9+1138 : TS = 26 , offset = 2.669
# WARNING:
#    Fit quality  3 Photon index =  3.2238560108355943
# ----Making TS Map
# ----Saving Results
# O19 : TS = 6
# ----Localizing O19
# Moved O19 by:  0.608 deg
# 99% positional uncertainty:  3.148 deg
# No convergence: localize() placed O19 >  0.4 deg away from original position.
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  O24
# here
# ----Finding sources around O24
# O24 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J1243.0+3950 : TS = 26 , offset = 0.944
# WARNING: 4FGL J1243.0+3950 proximity might interfere with the results for O24
# WARNING:
#    Fit quality  3 Photon index =  2.189214525514585
# ----Making TS Map
# ----Saving Results
# O24 : TS = 12
# ----Localizing O24
# Moved O24 by:  0.032 deg
# 99% positional uncertainty:  0.168 deg
# WARNING:
#    Fit quality  3 Photon index =  2.1341658410360123
# Dist. from 4FGL J1243.0+3950 = 0.971 deg
# O24 : (after localizing) TS = 14
# ----Making TS Map
# ----Saving Results
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  O66
# here
#
# Time for:  O67
# here
#
# Time for:  O70
# here
#
# Time for:  X2
#
# Time for:  X6
# here

# %%
retry = ['O5', 'O6', 'O16', 'O17', 'O19', 'O24', 'O66', 'O67', 'O70',
         'X2', 'X6', 'X9', 'X16', 'X17', 'X21', 'X27', 'X28', 'X29']

s = 6

for r in retry[s:]:
    do = [r]
    
    try:
        trace_profile(do, free_dist=5, loc_TS=4, loc_tol=0.8, opt='MINUIT', 
              load=False, trace=True, test_mocks=True, verb=1, make_plts=True)
    except:
        pass
    
    

from ipylab import JupyterFrontEnd
# save notebook and shutdown system
app = JupyterFrontEnd()
app.commands.execute('docmanager:save')

# !shutdown -h
# Out:
# Time for:  O66
# here
# ----Finding sources around O66
# O66 is 0.0 deg from the ROI center
# ----Closest source is PS J1140.6-0130 : TS = 28 , offset = 1.534
# WARNING:
#    Fit quality  3 Photon index =  2.90423595068561
# ----Making TS Map
# ----Saving Results
# O66 : TS = 2
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  O67
# here
# ----Finding sources around O67
# O67 is 0.0 deg from the ROI center
# ----Closest source is PS J1501.8-0220 : TS = 23 , offset = 1.725
# WARNING:
#    Fit quality  3 Photon index =  2.1195725674275336
# ----Making TS Map
# ----Saving Results
# O67 : TS = 6
# ----Localizing O67
# Moved O67 by:  0.154 deg
# 99% positional uncertainty:  0.25 deg
# WARNING:
#    Fit quality  3 Photon index =  2.250673012592082
# Dist. from PS J1501.8-0220 = 1.825 deg
# O67 : (after localizing) TS = 15
# ----Making TS Map
# ----Saving Results
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  O70
# here
# ----Finding sources around O70
# O70 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J1116.6+2915 : TS = 14 , offset = 1.123
# WARNING:
#    Fit quality  3 Photon index =  3.1910508706913236
# ----Making TS Map
# ----Saving Results
# O70 : TS = 3
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  X2
# here
# ----Finding sources around X2
# X2 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J0243.2-0550 : TS = 24 , offset = 2.826
# WARNING:
#    Fit quality  3 Photon index =  2.628623392894389
# ----Making TS Map
# ----Saving Results
# X2 : TS = 10
# ----Localizing X2
# Moved X2 by:  0.203 deg
# 99% positional uncertainty:  0.256 deg
# WARNING:
#    Fit quality  3 Photon index =  2.528298035403614
# Dist. from 4FGL J0243.2-0550 = 2.762 deg
# X2 : (after localizing) TS = 19
# ----Making TS Map
# ----Saving Results
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  X6
# here
# ----Finding sources around X6
# X6 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J2335.4-0128 : TS = 100 , offset = 1.277
# WARNING:
#    Fit quality  3 Photon index =  3.7657158162281283
# ----Making TS Map
# ----Saving Results
# X6 : TS = 3
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  X9
# here
# ----Finding sources around X9
# X9 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J1310.9+5514 : TS = 99 , offset = 1.399
# WARNING:
#    Fit quality  3 Photon index =  2.1037257974488126
# ----Making TS Map
# ----Saving Results
# X9 : TS = 2
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  X16
# here
# ----Finding sources around X16
# X16 is 0.0 deg from the ROI center
# ----Closest source is PS J1002.5+1218 : TS = 29 , offset = 1.484
# WARNING:
#    Fit quality  3 Photon index =  2.2976314197293117
# ----Making TS Map
# ----Saving Results
# X16 : TS = 1
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  X17
# here
# ----Finding sources around X17
# X17 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J1018.9+1043 : TS = 13 , offset = 2.576
# WARNING:
#    Fit quality  3 Photon index =  2.5207989396307937
# ----Making TS Map
# ----Saving Results
# X17 : TS = 13
# ----Localizing X17
# Moved X17 by:  0.188 deg
# 99% positional uncertainty:  0.269 deg
# WARNING:
#    Fit quality  3 Photon index =  2.400258881747772
# Dist. from 4FGL J1018.9+1043 = 2.634 deg
# X17 : (after localizing) TS = 19
# ----Making TS Map
# ----Saving Results
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  X21
# here
# ----Finding sources around X21
# X21 is 0.0 deg from the ROI center
# ----Closest source is PS J1140.7-0128 : TS = 29 , offset = 1.079
# WARNING:
#    Fit quality  2 Photon index =  2.698356119078073
# ----Making TS Map
# ----Saving Results
# X21 : TS = 0
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  X27
# here
# ----Finding sources around X27
# X27 is 0.0 deg from the ROI center
# ----Closest source is PS J1421.8+0253 : TS = 27 , offset = 1.232
# WARNING:
#    Fit quality  2 Photon index =  2.009699742874846
# ----Making TS Map
# ----Saving Results
# X27 : TS = 0
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  X28
# here
# ----Finding sources around X28
# X28 is 0.0 deg from the ROI center
# ----Closest source is PS J1437.8+0218 : TS = 31 , offset = 1.437
# WARNING:
#    Fit quality  2 Photon index =  3.035826364065076
# ----Making TS Map
# ----Saving Results
# X28 : TS = 1
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  X29
# here
# ----Finding sources around X29
# X29 is 0.0 deg from the ROI center
# ----Closest source is PS J1601.4+0635 : TS = 20 , offset = 2.06
# WARNING:
#    Fit quality  2 Photon index =  1.9999528833469167
# ----Making TS Map
# ----Saving Results
# X29 : TS = 0
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0

# %% [markdown]
# Re-do extended analysis > 500 MeV for most promissing sources

# %%
again = ['O16_2', 'O24_2','X2_2', 'X17_2', 'X24']

s = 0

for r in again[s:]:
    do = [r]
    
    try:
        trace_profile(do, free_dist=5, loc_TS=4, loc_tol=0.8, opt='MINUIT', 
              load=False, trace=True, test_mocks=True, verb=1, make_plts=True)
    except:
        pass
    
    

from ipylab import JupyterFrontEnd
# save notebook and shutdown system
app = JupyterFrontEnd()
app.commands.execute('docmanager:save')

# !shutdown -h
# Out:
# Time for:  O16_2
# here
# ----Finding sources around O16_2
# O16_2 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J0929.3+5014 : TS = 1345 , offset = 1.53
# WARNING:
#    Fit quality  3 Photon index =  2.10419041011946
# ----Making TS Map
# ----Saving Results
# O16_2 : TS = 12
# ----Localizing O16_2
# Moved O16_2 by:  0.152 deg
# 99% positional uncertainty:  0.148 deg
# WARNING: Original position is outside r99, localize failed
# Adding new point source
# WARNING:
#    Fit quality  2 Photon index =  1.7900600449686308
# O16_2 : (after localizing) TS = 0
# ----Making TS Map
# ----Saving Results
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  O24_2
# here
# ----Finding sources around O24_2
# O24_2 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J1243.0+3950 : TS = 36 , offset = 0.944
# WARNING: 4FGL J1243.0+3950 proximity might interfere with the results for O24_2
# WARNING:
#    Fit quality  3 Photon index =  2.3161170441888284
# ----Making TS Map
# ----Saving Results
# O24_2 : TS = 20
# ----Localizing O24_2
# Moved O24_2 by:  0.031 deg
# 99% positional uncertainty:  0.131 deg
# WARNING:
#    Fit quality  3 Photon index =  2.282543626342236
# Dist. from 4FGL J1243.0+3950 = 0.967 deg
# O24_2 : (after localizing) TS = 22
# ----Making TS Map
# ----Saving Results
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  X2_2
# here
# ----Finding sources around X2_2
# X2_2 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J0243.2-0550 : TS = 72 , offset = 2.826
# WARNING:
#    Fit quality  3 Photon index =  2.582512261270231
# ----Making TS Map
# ----Saving Results
# X2_2 : TS = 12
# ----Localizing X2_2
# Moved X2_2 by:  0.228 deg
# 99% positional uncertainty:  0.252 deg
# WARNING:
#    Fit quality  3 Photon index =  2.440394131094443
# Dist. from 4FGL J0243.2-0550 = 2.789 deg
# X2_2 : (after localizing) TS = 23
# ----Making TS Map
# ----Saving Results
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  X17_2
# here
# ----Finding sources around X17_2
# X17_2 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J1018.9+1043 : TS = 21 , offset = 2.576
# WARNING:
#    Fit quality  3 Photon index =  2.4235568430747607
# ----Making TS Map
# ----Saving Results
# X17_2 : TS = 15
# ----Localizing X17_2
# Moved X17_2 by:  0.13 deg
# 99% positional uncertainty:  0.345 deg
# WARNING:
#    Fit quality  3 Photon index =  2.452838913289008
# Dist. from 4FGL J1018.9+1043 = 2.682 deg
# X17_2 : (after localizing) TS = 16
# ----Making TS Map
# ----Saving Results
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  X24
# here
# ----Finding sources around X24
# X24 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J1233.7-0144 : TS = 533 , offset = 1.606
# WARNING:
#    Fit quality  3 Photon index =  4.816197357594959
# ----Making TS Map
# ----Saving Results
# X24 : TS = 2
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
# Shutdown scheduled for Fri 2022-04-29 01:12:10 -03, use 'shutdown -c' to cancel.

# %% [markdown]
# # X-ray sources

# %%
again = ['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X8', 'X11', 'X13', 'X19', 'X20', 'X24']

s = 0

for r in again[s:]:
    do = [r]
    
    try:
        trace_profile(do, free_dist=5, loc_TS=4, loc_tol=0.8, opt='MINUIT', 
              load=False, trace=True, test_mocks=True, verb=1, make_plts=True)
    except:
        pass
    
    

from ipylab import JupyterFrontEnd
# save notebook and shutdown system
app = JupyterFrontEnd()
app.commands.execute('docmanager:save')

# !shutdown -h
# Out:
# Time for:  X1
# here
# ----Finding sources around X1
# X1 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J0255.8+0534 : TS = 17 , offset = 0.53
# WARNING: 4FGL J0255.8+0534 proximity might interfere with the results for X1
# WARNING:
#    Fit quality  2 Photon index =  2.0053900219425875
# ----Making TS Map
# ----Saving Results
# X1 : TS = 0
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  X2
# here
# ----Finding sources around X2
# X2 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J0809.8+5218 : TS = 9106 , offset = 0.839
# WARNING: 4FGL J0809.8+5218 proximity might interfere with the results for X2
# WARNING:
#    Fit quality  3 Photon index =  4.999740613826782
# ----Making TS Map
# ----Saving Results
# X2 : TS = 2
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  X3
# here
# ----Finding sources around X3
# X3 is close to galactic plane: b = 28.405
# X3 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J0816.9+2050 : TS = 184 , offset = 0.672
# WARNING: 4FGL J0816.9+2050 proximity might interfere with the results for X3
# WARNING:
#    Fit quality  2 Photon index =  2.0182545531349816
# ----Making TS Map
# ----Saving Results
# X3 : TS = 0
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  X4
# here
# ----Finding sources around X4
# X4 is 0.0 deg from the ROI center
# ----Closest source is PS J0932.0+3632 : TS = 26 , offset = 0.96
# WARNING:
#    Fit quality  3 Photon index =  3.7305915204097975
# ----Making TS Map
# ----Saving Results
# X4 : TS = 3
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  X5
# here
# ----Finding sources around X5
# X5 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J1023.8+3002 : TS = 59 , offset = 1.196
# WARNING:
#    Fit quality  3 Photon index =  2.2575921476672267
# ----Making TS Map
# ----Saving Results
# X5 : TS = 0
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  X6
# here
# ----Finding sources around X6
# X6 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J1209.4+4118 : TS = 725 , offset = 1.841
# WARNING:
#    Fit quality  2 Photon index =  2.0056564068742184
# ----Making TS Map
# ----Saving Results
# X6 : TS = 0
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  X8
# here
# ----Finding sources around X8
# X8 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J1209.4+4118 : TS = 718 , offset = 1.167
# WARNING:
#    Fit quality  3 Photon index =  2.286063889863453
# ----Making TS Map
# ----Saving Results
# X8 : TS = 1
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  X11
# here
# ----Finding sources around X11
# X11 is 0.0 deg from the ROI center
# Closest source is PS J1219.6+0547 : TS = 52 , offset = 0.291 deg
# Moved PS J1219.6+0547 by:  0.013 deg, new offset = 0.279  deg
# 99% positional uncertainty:  0.084
# Target is outside r99
# WARNING:
#    Fit quality  2 Photon index =  1.093003456841307
# ----Making TS Map
# ----Saving Results
# X11 : TS = 1
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  X13
# here

# %%
again = ['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X8', 'X11', 'X13', 'X19', 'X20', 'X24']

s = -4

for r in again[s:]:
    do = [r]
    
    try:
        trace_profile(do, free_dist=5, loc_TS=4, loc_tol=0.8, opt='MINUIT', 
              load=False, trace=True, test_mocks=True, verb=1, make_plts=True)
    except:
        pass
    
    

from ipylab import JupyterFrontEnd
# save notebook and shutdown system
app = JupyterFrontEnd()
app.commands.execute('docmanager:save')

# !shutdown -h
# Out:
# Time for:  X13
# here
# ----Finding sources around X13
# X13 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J1424.1+2917 : TS = 11 , offset = 1.827
# WARNING:
#    Fit quality  2 Photon index =  2.0079512377628674
# ----Making TS Map
# ----Saving Results
# X13 : TS = 0
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  X19
# here
# ----Finding sources around X19
# X19 is 0.0 deg from the ROI center
# ----Closest source is PS J1524.8+1522 : TS = 28 , offset = 3.01
# WARNING:
#    Fit quality  2 Photon index =  2.0105301185770745
# ----Making TS Map
# ----Saving Results
# X19 : TS = 0
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  X20
# here
# ----Finding sources around X20
# X20 is 0.0 deg from the ROI center
# Closest source is PS J1614.4+5027 : TS = 23 , offset = 0.657 deg
# Moved PS J1614.4+5027 by:  0.009 deg, new offset = 0.656  deg
# 99% positional uncertainty:  0.105
# Target is outside r99
# WARNING:
#    Fit quality  2 Photon index =  2.0052011392923736
# ----Making TS Map
# ----Saving Results
# X20 : TS = 0
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  X24
# here
# ----Finding sources around X24
# X24 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J1632.5+3839 : TS = 163 , offset = 1.013
# WARNING:
#    Fit quality  2 Photon index =  2.0059669146715087
# ----Making TS Map
# ----Saving Results
# X24 : TS = 0
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
# Shutdown scheduled for Mon 2022-05-02 15:25:55 -03, use 'shutdown -c' to cancel.

# %%
#!pip install ipylab
from ipylab import JupyterFrontEnd

# save notebook and shutdown system
app = JupyterFrontEnd()
app.commands.execute('docmanager:save')

# !shutdown -h
# Out:
# Shutdown scheduled for Fri 2022-03-11 14:59:22 -03, use 'shutdown -c' to cancel.

# %% [markdown]
# # Control sample of SG galaxies

# %%
# Star-forming control sample (up to SF25 are BPT selecte, the rest have radio detections)
SF = ['SF1', 'SF2', 'SF3', 'SF4', 'SF5', 'SF6', 'SF7', 'SF8', 'SF9', 'SF10', 
      'SF11', 'SF12', 'SF13', 'SF14', 'SF15', 'SF16', 'SF17', 'SF18', 'SF19', 'SF20',
      'SF21', 'SF22', 'SF23', 'SF24', 'SF25', 'SF26', 'SF27', 'SF28', 'SF29', 'SF30', 
      'SF31', 'SF32', 'SF33', 'SF34', 'SF35', 'SF36','SF37', 'SF38', 'SF39']

NSA_sf = ['33370', '33910', '34460', '35004', '35300', '35606', '36037', '36479', '37136', '37394',
          '37628', '37839', '38174', '38589', '38846', '39261', '39560', '39902', '40057', '40382',
          '42516', '42652', '43019', '43236', '43536', '128822','131181','157149', '135896', '157771', 
          '27164', '34462', '34520', '906', '159841', '88778', '3264', '30972', '39149']
          
paper_sf = ['SF25/none', 'RR7','RR11', 'RR30', 'RR31', 'RR42',
            'RR43', 'RR49', 'RR54', 'RR59', 'RR62', 'RR72', 'RR74', 'RR91', 'RR106']

# non convergent ROIs
noconv_sf = []




############# broad Ha () galaxies (we wont use these yet)
bSF = ['bSF1', 'bSF2', 'bSF3', 'bSF4', 'bSF5', 
      'bSF6', 'bSF7', 'bSF8', 'bSF9', 'bSF10', 
      'bSF11', 'bSF12', 'bSF13', 'bSF14']

paper_bsf = ['RO_A', 'RO_B/BalX', 'RO_C', 'RO_D', 'RO_E',
            'RO_F','RO_G','RO_H', 'RO_I','RO_J',
            'RO_K','RO_L','RO_M','RO_O']

NSA_bsf = ['22083', '15952', '109990', '76788', '109016',
          '12793', '13496', '74914', '112250','41331', 
          '91579', '33207', '119311', '104565', '128822', 
          '131181', '157149', '135896', '157771', '27164',
          '34462', '34520', '906', '159841', '88778', '3264', '30972', '39149']
#######################

print(len(SF))
# Out:
# 39

# %%
s = 0
trace_profile(SF[s:], free_dist=5, loc_tol=0.8, opt='MINUIT', 
              load=False, trace=True, test_mocks=True, verb=1, make_plts=True)
# Out:
# Time for:  SF1
# here
# ----Finding sources around SF1
# SF1 is close to galactic plane: b = 28.077
# SF1 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J0752.2+3313 : TS = 790 , offset = 1.728
# WARNING:
#    Fit quality  2 Photon index =  2.0009427513761464
# ----Making TS Map
# ----Saving Results
# SF1 : TS = 0
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  SF2
# here
# ----Finding sources around SF2
# SF2 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J0903.1+4652 : TS = 324 , offset = 1.109
# WARNING:
#    Fit quality  2 Photon index =  2.0085277547445526
# ----Making TS Map
# ----Saving Results
# SF2 : TS = 0
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  SF3
# here
# ----Finding sources around SF3
# SF3 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J1035.3+5541 : TS = 45 , offset = 1.391
# WARNING:
#    Fit quality  2 Photon index =  2.007520116028113
# ----Making TS Map
# ----Saving Results
# SF3 : TS = 0
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  SF4
# here
# ----Finding sources around SF4
# SF4 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J1354.3-0206 : TS = 15 , offset = 1.093
# WARNING:
#    Fit quality  2 Photon index =  2.0126306255914774
# ----Making TS Map
# ----Saving Results
# SF4 : TS = 0
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  SF5
# here
# ----Finding sources around SF5
# SF5 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J1425.4-0119 : TS = 39 , offset = 2.011
# WARNING:
#    Fit quality  2 Photon index =  2.004561827833406
# ----Making TS Map
# ----Saving Results
# SF5 : TS = 0
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  SF6
# here
# ----Finding sources around SF6
# SF6 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J1520.8-0348 : TS = 866 , offset = 2.127
# WARNING:
#    Fit quality  2 Photon index =  2.0056194885434926
# ----Making TS Map
# ----Saving Results
# SF6 : TS = 0
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  SF7
# here
# ----Finding sources around SF7
# SF7 is 0.0 deg from the ROI center
# ----Closest source is PS J0833.1+3259 : TS = 35 , offset = 1.51
# WARNING:
#    Fit quality  2 Photon index =  2.0015503485874713
# ----Making TS Map
# ----Saving Results
# SF7 : TS = 0
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  SF8
# here
# ----Finding sources around SF8
# SF8 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J0950.2+4553 : TS = 358 , offset = 1.757
# WARNING:
#    Fit quality  2 Photon index =  2.006450658546265
# ----Making TS Map
# ----Saving Results
# SF8 : TS = 0
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  SF9
# here
# ----Finding sources around SF9
# SF9 is 0.0 deg from the ROI center
# Closest source is PS J1117.4+5858 : TS = 44 , offset = 0.463 deg
# Moved PS J1117.4+5858 by:  0.018 deg, new offset = 0.459  deg
# 99% positional uncertainty:  0.067
# Target is outside r99
# WARNING:
#    Fit quality  2 Photon index =  1.9982601832001732
# ----Making TS Map
# ----Saving Results
# SF9 : TS = 0
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  SF10
# here
# ----Finding sources around SF10
# SF10 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J1154.0+6018 : TS = 66 , offset = 0.863
# WARNING: 4FGL J1154.0+6018 proximity might interfere with the results for SF10
# WARNING:
#    Fit quality  2 Photon index =  2.0047238097172206
# ----Making TS Map
# ----Saving Results
# SF10 : TS = 0
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  SF11
# here
# ----Finding sources around SF11
# SF11 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J1248.3+5820 : TS = 16751 , offset = 1.471
# WARNING:
#    Fit quality  2 Photon index =  2.0095922818796828
# ----Making TS Map
# ----Saving Results
# SF11 : TS = 0
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  SF12
# here
# ----Finding sources around SF12
# SF12 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J1331.0+5653 : TS = 87 , offset = 1.883
# WARNING:
#    Fit quality  2 Photon index =  2.0187845786435608
# ----Making TS Map
# ----Saving Results
# SF12 : TS = 0
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  SF13
# here
# ----Finding sources around SF13
# SF13 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J1124.9+4934 : TS = 630 , offset = 1.425
# WARNING:
#    Fit quality  3 Photon index =  2.4319116151065674
# ----Making TS Map
# ----Saving Results
# SF13 : TS = 8
# ----Localizing SF13
# Moved SF13 by:  0.137 deg
# 99% positional uncertainty:  0.11 deg
# WARNING: Original position is outside r99, localize failed
# Adding new point source
# WARNING:
#    Fit quality  3 Photon index =  2.209666360448192
# SF13 : (after localizing) TS = 0
# ----Making TS Map
# ----Saving Results
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  SF14
# here
# ----Finding sources around SF14
# SF14 is 0.0 deg from the ROI center
# ----Closest source is PS J1206.8+4741 : TS = 23 , offset = 1.209
# WARNING:
#    Fit quality  2 Photon index =  2.0003185681445244
# ----Making TS Map
# ----Saving Results
# SF14 : TS = 0
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  SF15
# here
# ----Finding sources around SF15
# SF15 is 0.0 deg from the ROI center
# ----Closest source is PS J1656.0+3246 : TS = 20 , offset = 0.839
# WARNING:
#    Fit quality  2 Photon index =  2.0063825642508166
# ----Making TS Map
# ----Saving Results
# SF15 : TS = 0
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  SF16
# here
# ----Finding sources around SF16
# SF16 is close to galactic plane: b = -23.673
# SF16 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J2043.7+0000 : TS = 77 , offset = 1.232
# WARNING:
#    Fit quality  2 Photon index =  2.0047632455560094
# ----Making TS Map
# ----Saving Results
# SF16 : TS = 0
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  SF17
# here
# ----Finding sources around SF17
# SF17 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J2118.0+0019 : TS = 10 , offset = 0.855
# WARNING: 4FGL J2118.0+0019 proximity might interfere with the results for SF17
# WARNING:
#    Fit quality  3 Photon index =  1.3644339231392333
# ----Making TS Map
# ----Saving Results
# SF17 : TS = 4
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  SF18
# here
# ----Finding sources around SF18
# SF18 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J0924.0+0534 : TS = 58 , offset = 0.396
# WARNING: 4FGL J0924.0+0534 proximity might interfere with the results for SF18
# WARNING:
#    Fit quality  3 Photon index =  2.1841338653330924
# ----Making TS Map
# SF18 : TS = 0
# Done!
#
#
# Time for:  SF19
# here
# ----Finding sources around SF19
# SF19 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J1008.0+0620 : TS = 775 , offset = 0.985
# WARNING: 4FGL J1008.0+0620 proximity might interfere with the results for SF19
# WARNING:
#    Fit quality  2 Photon index =  1.6652019798403166
# ----Making TS Map
# ----Saving Results
# SF19 : TS = 0
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  SF20
# here
# ----Finding sources around SF20
# SF20 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J1043.6+0654 : TS = 29 , offset = 0.645
# WARNING: 4FGL J1043.6+0654 proximity might interfere with the results for SF20
# WARNING:
#    Fit quality  3 Photon index =  2.5082256967397947
# ----Making TS Map
# ----Saving Results
# SF20 : TS = 0
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  SF21
# here
# ----Finding sources around SF21
# SF21 is 29.601 deg from the ROI center
# ----Closest source is 4FGL J2206.8-0032 : TS = 511 , offset = 1.404
# ----Closest source is 4FGL J2156.3-0036 : TS = 126 , offset = 1.489
# WARNING:
#    Fit quality  3 Photon index =  1.999999898623123
# ----Making TS Map
# ----Saving Results
# SF21 : TS = 0
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  SF22
# here
# ----Finding sources around SF22
# SF22 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J2244.9-0007 : TS = 24 , offset = 0.741
# WARNING: 4FGL J2244.9-0007 proximity might interfere with the results for SF22
# WARNING:
#    Fit quality  2 Photon index =  2.0054247608931783
# ----Making TS Map
# ----Saving Results
# SF22 : TS = 0
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  SF23
# here
# ----Finding sources around SF23
# SF23 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J1411.8+5249 : TS = 145 , offset = 0.949
# WARNING: 4FGL J1411.8+5249 proximity might interfere with the results for SF23
# WARNING:
#    Fit quality  2 Photon index =  2.089307424672585
# ----Making TS Map
# ----Saving Results
# SF23 : TS = 0
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
#
#
# Time for:  SF24
# here
# ----Finding sources around SF24
# SF24 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J1500.7+4752 : TS = 99 , offset = 0.314
# WARNING: 4FGL J1500.7+4752 proximity might interfere with the results for SF24
# WARNING:
#    Fit quality  3 Photon index =  1.5956817752952164
# ----Making TS Map
# SF24 : TS = 0
# Done!
#
#
# Time for:  SF25
# here
# ----Finding sources around SF25
# SF25 is 0.0 deg from the ROI center
# ----Closest source is 4FGL J1549.3+4234 : TS = 53 , offset = 1.073
# WARNING:
#    Fit quality  3 Photon index =  2.2854972808501763
# ----Making TS Map
# ----Saving Results
# SF25 : TS = 5
# ----Saving Results
# ----Tracing TS profile
# Fit ok
# Index = 0.5
# ----Generating mock sources
# Fit ok
# Index = 0.909
# Fit ok
# Index = 1.318
# Fit ok
# Index = 1.727
# Fit ok
# Index = 2.136
# Fit ok
# Index = 2.545
# Fit ok
# Index = 2.955
# Fit ok
# Index = 3.364
# Fit ok
# Index = 3.773
# Fit ok
# Index = 4.182
# Fit ok
# Index = 4.591
# Fit ok
# Index = 5.0
# Done!
